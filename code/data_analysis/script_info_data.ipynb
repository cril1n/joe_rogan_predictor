# %%
import pandas as pd

guests = pd.read_csv('../gemini/gem_data/data_final.csv')

guests
# Out:
#          video_id                 Nome Nazionalità Sesso   Età  \
# 0     hBMoPUAeLnY         Donald Trump     America     M  78.0
# 1     Ah6kirkSwTg       Douglas Murray      Europa     M  44.0
# 2     Ah6kirkSwTg           Dave Smith     America     M  42.0
# 3     nNxzn-vRodY            Ron White     America     M  67.0
# 4     NRVEkc9lxH0             Ben Lamm     America     M  40.0
# ...           ...                  ...         ...   ...   ...
# 2179  p0zNBUF-nR4     Andrew Dice Clay     America     M  66.0
# 2180  3F7y0U6L6cI           Steve Volk     America     M  50.0
# 2181  ZpHh_TU2kcI  Neil Degrasse Tyson     America     M  65.0
# 2182  WPt2Ec1QJlk        Steve Rinella     America     M  50.0
# 2183  WPt2Ec1QJlk         Bryan Callen     America     M  57.0
#
#                        Professione              Notorietà  \
# 0                  Politica/Affari   Personaggio Pubblico
# 1              Autore/Commentatore   Personaggio Pubblico
# ...

# %%
guests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2184 entries, 0 to 2183
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   video_id                   2184 non-null   object
#  1   Nome                       2184 non-null   object
#  2   Nazionalità                2184 non-null   object
#  3   Sesso                      2184 non-null   object
#  4   Età                        2184 non-null   float64
#  5   Professione                2184 non-null   object
#  6   Notorietà                  2184 non-null   object
#  7   Numero di follower social  2184 non-null   object
#  8   Topic video                2184 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 153.7+ KB
